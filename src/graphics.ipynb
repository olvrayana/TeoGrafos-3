# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1, 2, 3, 4, 5, 6])
y = np.array([0.0660, 0.1711, 0.3288, 8.2726, 41.2808, 40.9873 ])

plt.bar(x, y)
plt.title('Exec. Time')
# Out:
# Text(0.5, 1.0, 'Exec. Time')

# %%
x = np.array([1, 2, 3, 4, 5, 6])
y = np.array([1058, 11189, 2964, 13486, 26360, 26812])

plt.bar(x, y)
plt.title('Flow')
plt.show()
